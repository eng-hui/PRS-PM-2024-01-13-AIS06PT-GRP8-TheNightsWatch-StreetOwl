# %%
from cnn_model import CNNModel

model = CNNModel()

# %%
from torchview import draw_graph

model_graph = draw_graph(model, input_size=(1,3,512,512), expand_nested=True, hide_inner_tensors=False,hide_module_functions=True,save_graph=True,filename='density_model_graph')
model_graph.visual_graph
# Out:
# (dot.exe:56744): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.
#
# (dot.exe:2704): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.
